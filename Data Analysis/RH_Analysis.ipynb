# %%
# Importing Required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.pyplot import figure
import datetime
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
wr_df = pd.read_csv('wr.csv',low_memory=False)

# %%
wr_df.columns
# Out:
# Index(['wr_dummy', 'wr_sdate', 'wr_sshift', 'wr_year', 'wr_month', 'wr_period',
#        'wr_studyno', 'wr_studyid', 'wr_ucode', 'wr_dcode', 'wr_mcode',
#        'wr_sno', 'wr_count', 'wr_mixcod', 'wr_acount', 'wr_sentdt', 'wr_recdt',
#        'wr_studytm', 'wr_ctype', 'wr_rkmfactor', 'wr_gcode', 'wr_weight',
#        'wr_splno', 'wr_elper', 'wr_samln', 'wr_lnunt', 'wr_cunt', 'wr_sunt',
#        'wr_rejcr', 'wr_tolmt', 'wr_ehnk', 'wr_estr', 'wr_fibre', 'wr_usrid',
#        'wr_updt', 'wr_uptim', 'wr_studycode', 'wr_stren', 'wr_nosmp',
#        'wr_dtemp', 'wr_wtemp', 'wr_rh', 'wr_ccf', 'wr_scf', 'wr_reqcv',
#        'wr_reqscv', 'wr_macty', 'wr_chpin', 'wr_wcadv', 'wr_wcadl', 'wr_wcval',
#        'wr_status', 'wr_strid', 'wr_avgcnt', 'wr_avgstr', 'wr_ccvper',
#        'wr_scvper', 'wr_sname', 'wr_tcmpl', 'wr_csp', 'wr_ccname', 'wr_scname',
#        'wr_crej', 'wr_srej', 'wr_sqrtsamp', 'wr_sqrtmc', 'wr_tmpunit',
#        'wr_sstatus', 'wr_sremark', 'wr_uremark', 'wr_noticed',
#        'wr_disposition', 'wr_review', 'wr_testdes', 'wr_lwk', 'wr_del',
#        'wr_adcval', 'wr_lcmaxstr', 'wr_sdel'],
#       dtype='object')

# %%
wr_df['wr_count']=='60C'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 621251    False
# 621252    False
# 621253    False
# 621254    False
# 621255    False
# 621256    False
# 621257    False
# 621258    False
# 621259    False
# 621260    False
# 621261    False
# 621262    False
# 621263    False
# 621264    False
# 621265    False
# 621266    False
# 621267    False
# 621268    False
# 621269    False
# 621270    False
# 621271    False
# 621272    False
# 621273    False
# 621274    False
# 621275    False
# 621276    False
# 621277    False
# 621278    False
# 621279    False
# 621280    False
# Name: wr_count, Length: 621281, dtype: bool

# %%
wr_t_df  = wr_df[wr_df['wr_count']=='60C']

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.scatter(wr_t_df['wr_rh'], wr_t_df['wr_csp'])
plt.show()

# %%
wr_t_df.head()
# Out:
#       wr_dummy    wr_sdate  wr_sshift  wr_year  wr_month  wr_period  \
# 2928         0  2016-09-27          1      NaN         0          0
# 2961         0  2016-09-27          1      NaN         0          0
# 2971         0  2016-09-27          1      NaN         0          0
# 2995         0  2016-09-27          1      NaN         0          0
# 3011         0  2016-09-27          1      NaN         0          0
#
#       wr_studyno  wr_studyid wr_ucode wr_dcode  ... wr_uremark  wr_noticed  \
# 2928           1           0        A       FN  ...        NaN         NaN
# 2961           1           0        A       FN  ...        NaN         NaN
# 2971           1           0        A       FN  ...        NaN         NaN
# 2995           1           0        A       FN  ...        NaN         NaN
# 3011           1           0        A       FN  ...        NaN         NaN
#
#      wr_disposition wr_review                   wr_testdes  wr_lwk  wr_del  \
# 2928            NaN       NaN  SPG-7  M349   60CW  TPI31.9       0      -1
# 2961            NaN       NaN  SPG-7  M349   60CW  TPI31.9       0      -1
# 2971            NaN       NaN  SPG-7  M349   60CW  TPI31.9       0      -1
# 2995            NaN       NaN  SPG-7  M349   60CW  TPI31.9       0      -1
# 3011            NaN       NaN  SPG-7  M349   60CW  TPI31.9       0      -1
#
#       wr_adcval wr_lcmaxstr  wr_sdel
# 2928       12.5     550 lbs        0
# 2961       12.5     550 lbs        0
# 2971       12.5     550 lbs        0
# 2995       12.5     550 lbs        0
# 3011       12.5     550 lbs        0
#
# [5 rows x 79 columns]
