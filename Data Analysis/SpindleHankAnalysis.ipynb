# %%
# Importing Required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Reading Files
prod_t_df = pd.read_csv('pt.csv',low_memory=False)

# %%
#Selecting Required Columns
speed_hanks = prod_t_df[['pt_date','pt_mcode','pt_avgsspd','pt_hanks']]

# %%
# RingFrame Machines Only
speed_hanks = speed_hanks[speed_hanks.pt_mcode.str.contains('^RF')]

# %%
speed_hanks = speed_hanks.sort_values(by='pt_date')

# %%
# Date at Year 2019 month April
'''
speed_hanks_19 = speed_hanks[speed_hanks.pt_date.str.contains('2019$')]
dates = speed_hanks_18['pt_date']
dates =dates[dates.str.match('.{3}04.{3}')]
dates.unique()
'''
# Out:
# "\nspeed_hanks_19 = speed_hanks[speed_hanks.pt_date.str.contains('2019$')]\ndates = speed_hanks_18['pt_date']\ndates =dates[dates.str.match('.{3}04.{3}')]\ndates.unique()\n"

# %%
# Machines at Year 2019 month April

# %%
#plotting values
speed_hanks['pt_avgsspd'].plot(kind='box', figsize=(10, 50), color='blue')

# %%
speed_hanks[['pt_avgsspd','pt_hanks']].plot(kind='scatter', x='pt_avgsspd', y='pt_hanks', figsize=(10, 6), color='darkblue')
